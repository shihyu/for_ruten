# %% [markdown]
# # 主成分分析(PCA)：三維降至二維的簡單實例
#
# #### #此篇文章參考自 http://sebastianraschka.com/Articles/2014_pca_step_by_step.html#

# %% [markdown]
# ## 1. 產生一些三維的資料
# $
# \overrightarrow{\mu_1}=
#     \left [
#     \begin{array}{ccc}
#     0 \\
#     0 \\
#     0
#     \end{array}
#     \right ]
# $
# $
# \overrightarrow{\mu_2}=
#     \left [
#     \begin{array}{ccc}
#     1 \\
#     1 \\
#     1
#     \end{array}
#     \right ]
# $ (sample means)
#
# $
# \overrightarrow{\Sigma_1}=
#     \left [
#     \begin{array}{ccc}
#     1 & 0 & 0 \\
#     0 & 1 & 0 \\
#     0 & 0 & 1
#     \end{array}
#     \right ]
# $
# $
# \overrightarrow{\Sigma_2}=
#     \left [
#     \begin{array}{ccc}
#     1 & 0 & 0 \\
#     0 & 1 & 0 \\
#     0 & 0 & 1
#     \end{array}
#     \right ]
# $ (covariance matrices)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np

# %%
np.random.seed(0)

mu_vec1 = np.array([0,0,0])
cov_mat1 = np.array([[1,0,0],[0,1,0],[0,0,1]])
class1_sample = np.random.multivariate_normal(mu_vec1,cov_mat1,20).T
assert class1_sample.shape == (3,20), "The matrix has not the dimensons 3x20"

mu_vec2 = np.array([1,1,1])
cov_mat2 = np.array([[1,0,0],[0,1,0],[0,0,1]])
class2_sample = np.random.multivariate_normal(mu_vec1,cov_mat1,20).T
assert class2_sample.shape == (3,20), "The matrix has not the dimensons 3x20"

# %%
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mpl_toolkits.mplot3d import proj3d

fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')
plt.rcParams['legend.fontsize'] = 10
ax.plot(class1_sample[0,:], class1_sample[1,:], class1_sample[2,:], 'o', markersize=8, color='blue', alpha=0.5, label='class1')
ax.plot(class2_sample[0,:], class2_sample[1,:], class2_sample[2,:], '^', markersize=8, color='red' , alpha=0.5, label='class2')

plt.title('Samples for class 1 and class 2')
ax.legend(loc='upper right')
plt.show()

# %% [markdown]
# # 2. 將資料的標籤去除

# %%
all_samples = np.concatenate((class1_sample,class2_sample), axis=1)
assert all_samples.shape == (3,40), "The matrix has not the dimensions 3x40"

# %% [markdown]
# # 3. 建構三維的mean vector

# %%
mean_x = np.mean(all_samples[0,:])
mean_y = np.mean(all_samples[1,:])
mean_z = np.mean(all_samples[2,:])

mean_vector = np.array([[mean_x],[mean_y],[mean_z]])

print 'Mean Vector:\n', mean_vector
# Out:
# Mean Vector:
# [[ 0.19887368]
#  [ 0.30019884]
#  [-0.10123728]]

# %% [markdown]
# # 4. 建構Scatter Matrix
#
# The scatter matrix is computed by the following equation:
#
# ### $ S = \displaystyle\sum_{k=1}^{n}(x_{k}-m)(x_{k}-m)^{T}$
#
# where $m$ is the mean vector
#
# ### $ m = \frac{1}{n}\displaystyle\sum_{k=1}^{n}x_{k}$
